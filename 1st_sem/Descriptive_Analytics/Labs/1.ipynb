# %% [markdown]
# Write add, sub, div, and multiply aggregation using python

# %%
import numpy as np
import statistics as st

# %%
a= int(input("Give first num: "))
b= int(input("Give Second Num: "))

# %%
print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# 47
# -11
# 0.6206896551724138
# 522

# %%
c=[1,2,3,4,5,6,7,7,8,90,12,3,12,3,23,1,2,31,23,1,23,1,23,1]

# %%
print(f"mean: {np.mean(c)}")
print(f"median: {np.median(c)}")
print(f"standard deviation: {np.std(c)}")
# Out:
# mean: 12.166666666666666
# median: 5.5
# standard deviation: 18.474456840609836
